# %% [markdown]
# # BioCampus workshop: What you need to know about QuPath for fluorescence and IHC images analysis
#
# ## Proposed by Montpellier Ressources Imagerie
#
# **Trainers:**
#
# - BAECKER Volker
# - BENEDETTI Clément
# - HASSEN-KHODJA Cédric
#
# **Requirements:** [Requirements & installation guide](exercises/extras/install-requirements.html)

# %% [markdown]
# ## Program
#
# ### 1. Project creation
#
# - [Lecture](lectures/project-creation.html)
#
# - [Slides](pdfs/1-project-creation.pdf)
#
# - [Ex 1: Creating a new project](exercises/project-creation/ex1.html)
# - [Ex 2: Sharing a project](exercises/project-creation/ex2.html)
# - [Ex 3: Organizing the images in a project](exercises/project-creation/ex3.html)
#
# ### 2. Navigation, Annotations, Measurements
#
# - [Lecture](lectures/navigation-annotations-measurements.html)
#
# - [Slides](pdfs/2-navigation.pdf)
#
# - [Ex 1: Creating an annotation](exercises/annotations/ex1.html)
# - [Ex 2: Area, line and point annotations](exercises/annotations/ex2.html)
# - [Ex 3: Annotation hieararchy](exercises/annotations/ex3.html)
# - [Ex 4: Annotation measurements](exercises/annotations/ex4.html)
# - [Ex 5: The magic wand tool](exercises/annotations/ex5.html)
# - [Ex 6: Classifying annotations](exercises/annotations/ex6.html)
# - [Ex 7: Splitting annotations](exercises/annotations/ex7.html)
#
# ### 3. Stain Separation / Color Deconvolution
#
# - [Lecture](lectures/stain-separation-color-deconvolution.html)
#
# - [Slides](pdfs/3-stain-separation-by-color-deconvolution.pdf)
#
# - [Ex 1: Using standard stain vectors](exercises/color-deconvolution/ex1.html)
# - [Ex 2: Setting the stain vectors from the image](exercises/color-deconvolution/ex2.html)
# - [Ex 3: Automatic stain vector estimation](exercises/color-deconvolution/ex3.html)
#
# ### 4. Tissue segmentation and classification
#
# - [Lecture](lectures)
#
# - [Slides](pdfs/4-tissue-segmentation-and-classification.pdf)
#
# - [Ex 1: Fully manual segmentation](exercises/tissue-classification-segmentation/ex1.html)
# - [Ex 2: Using a threshold pixel classifier](exercises/tissue-classification-segmentation/ex2.html)
# - [Ex 3: Using a N-classes pixel classifier](exercises/tissue-classification-segmentation/ex3.html)
# - [Ex 4: Semi-automatic segmentation using SAM](exercises/tissue-classification-segmentation/ex4.html)
# - [Ex 5: Segmentation quality control](exercises/tissue-classification-segmentation/ex5.html)
# - [Ex 6: Area of signal per slide](exercises/tissue-classification-segmentation/ex6.html)
#
# ### 5. Cell Detection
#
# - [Lecture](lectures)
#
# - [Slides](pdfs/5-cells-detection.pdf)
#
# - [Ex 1: QuPath built-in method](exercises/cells-detection-segmentation/ex1.html)
# - [Ex 2: Use StarDist in QuPath](exercises/cells-detection-segmentation/ex2.html)
# - [Ex 3: Segmentation quality control](exercises/cells-detection-segmentation/ex3.html)
# - [Ex 4: Use CellPose in QuPath](exercises/cells-detection-segmentation/ex4.html)
# - [Ex 5: Use InstanSeg in QuPath](exercises/cells-detection-segmentation/ex5.html)
#
# ### 6. Cell Classification
#
# - [Lecture](lectures)
#
# - [Slides](pdfs/6-cells-classification.pdf)
#
# - [Ex 1: Using a threshold object classifier](exercises/cells-classification/ex1.html)
# - [Ex 2: Using a N-classes object classifier](exercises/cells-classification/ex2.html)
#
# ### 7. Multiplex Analysis
#
# - [Lecture](lectures/multiplex-analysis.html)
#
# - [Slides](pdfs/7-Multiplex-Analysis.pdf)
#
# - [Exercise](exercises)
