# %% [markdown]
# # BioCampus workshop: What you need to know about QuPath for fluorescence and IHC images analysis
#
# ## Proposed by Montpellier Ressources Imagerie
#
# **Trainers:**
#
# - BAECKER Volker
# - BENEDETTI Clément
# - HASSEN-KHODJA Cédric
#
# **Requirements:**
#
# - [QuPath 0.6.x](https://qupath.github.io/)
# - [MiniConda](https://repo.anaconda.com/miniconda/)
# - [Excel/LibreOffice Calc](https://fr.libreoffice.org/download/telecharger-libreoffice/)

# %% [markdown]
# ## Program
#
# ### 1. Project creation
#
# - [Lecture](lectures)
# - [Exercise](exercises)
#
# ### 2. Navigation, Annotations, Measurements
#
# - [Lecture](lectures)
# - [Exercise](exercises)
#
# ### 3. Stain Separation / Color Deconvolution
#
# - [Lecture](lectures)
# - [Exercise](exercises)
#
# ### 4. Tissue segmentation and classification
#
# - [Lecture](lectures)
# - [Ex 1: Fully manual segmentation](exercises/tissue-classification-ex1.html)
# - [Ex 2: Using a threshold pixel classifier](exercises)
# - [Ex 3: Using a N-classes pixel classifier](exercises)
#
# ### 5. Cell Detection
#
# - [Lecture](lectures)
# - [Exercise](exercises)
#
# ### 6. Cell Classification
#
# - [Lecture](lectures)
# - [Exercise](exercises)
#
# ### 7. Multiplex Analysis
#
# - [Lecture](lectures)
# - [Exercise](exercises)
