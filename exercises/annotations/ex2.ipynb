# %% [markdown]
# | [![back](../../media/navigation/back.png)](../../exercises/annotations/ex1.html) | [![home](../../media/navigation/home.png)](../../index.html) | [![next](../../media/navigation/next.png)](../../exercises/annotations/ex3.html) |
# | :---: | :---: | :---: |
# | Ex 2.1: Creating an annotation and setting its properties | • | Ex 2.3: Annotation Hierarchy |

# %% [markdown]
# ## 2.2 Area, Line and Point Annotations

# %% [markdown]
# Aim:
#  - Get to know the different annotation tools
#  - Lock annotations to avoid manipulations

# %% [markdown]
# ### 2.1.1 The different annotation types

# %% [markdown]
#  Make 2 arbitrary annotations of each annotation type. Select an annotation and look at the measurements on the annotations-tab.

# %% [markdown]
# <center>
# <img src="../../media/qupath-navigation/annotations of different types.png" alt="annotations of different types" >
# <br>
# <small>
# Fig. 2.2.1 &ndash; Annotations of different types.
# </small>
# </center>

# %% [markdown]
# What measurements are displayed for
# - area annotations?
# - line annotations?
# - point annotations?

# %% [markdown]
# ### 2.1.2 Locking annotations

# %% [markdown]
# Double-click an annotation and change its size, using the handles that appear when the annotation is selected.
#
# Now select all annotations in the annotations list and lock them. Then try again to change the size of one of the annotations.
#
# What has happened?

# %% [markdown]
# <center>
# <img src="../../media/qupath-navigation/no_handles.png" alt="selected locked annotation" >
# <br>
# <small>
# Fig. 2.2.2 &ndash; The selected annotation has no handles because it is locked and can not be modified.
# </small>
# </center>
